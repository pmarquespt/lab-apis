# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
CLIENT_ID = "<introduce your client id>"
CLIENT_SECRET = "<introduce your client secret>"

# %%
CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

# %%
# If you havent done so, install the spotipy wrapper
 # !pip install spotipy

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let"s use the search method by introducing a "query". For example, let"s try searching for "Lady Gaga":

# %%
results = sp.search(q="Lady Gaga", limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
# ...

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let"s check the values
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 1000

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Lady Gaga

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '0SiywuOBRcynK0uKGWdCnn'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Bad Romance'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 87

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it"s the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:0SiywuOBRcynK0uKGWdCnn'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist"s name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist"s name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist"s name. The method requires a `q` parameter, which is your query (in this case, the artist"s name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated "artists" field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist"s details, you can extract the "id" field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist"s ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist"s ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You"ll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you"re confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
 #   1_1 . **List Your Favorite Artists**:
 #- Make a list of your three favorite artists and store it in a variable named `artists`


artists = ["maroon 5", "Rui Veloso", "Joao Pedro Pais"]

# %%
# 2. **Fetch Top Tracks**:
    # 2_1 - Write a function named `get_top_tracks`.
    #     - This function should accept an artist"s name and return the name of the first 5 top tracks by that artist
    #     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` 
    #       list and store the results in a new list named `top_tracks_list

# %%
import requests

client_id = "4109b2d9f5014671863bb2df1d1fbdd3"
client_secret = "5cb719fae80c4191a9c0b288f51bfe50"



def get_top_tracks(artist_name):
  
    url = "https://accounts.spotify.com/api/token"
    auth_response = requests.post(url, {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,})
    
    
    
    
    auth_response_data = auth_response.json()
    access_token = auth_response_data["access_token"]
    
    

    search_url = f"https://api.spotify.com/v1/search?q={artist_name}&type=artist"
    search_response = requests.get(search_url, headers={
        "Authorization": f"Bearer {access_token}"})
    
    
    artist_data = search_response.json()
    
    if "artists" in artist_data and "items" in artist_data["artists"] and len(artist_data["artists"]["items"]) > 0:
        artist_id = artist_data["artists"]["items"][0]["id"]
        top_tracks_url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks?country=US"
        top_tracks_response = requests.get(top_tracks_url, headers={
            "Authorization": f"Bearer {access_token}"})
        top_tracks_data = top_tracks_response.json()
        
        top_tracks = [track["name"] for track in top_tracks_data["tracks"][:5]]
        return top_tracks
    else:
        return []


artists = ["maroon 5", "Rui Veloso", "Joao Pedro Pais"]


top_tracks_list = [get_top_tracks(artist) for artist in artists]
print(top_tracks_list)
# Out:
# [['Maps', 'Payphone', 'Moves Like Jagger - Studio Recording From "The Voice" Performance', 'Memories', 'This Love'], ['A paixão (Segundo Nicolau da Viola)', 'Não há estrelas no céu', 'Porto Côvo', 'Nunca me esqueci de ti - Live', 'Porto sentido'], ['Mentira', 'Ninguém é de ninguém', 'Fazes-me Falta', 'Mentira', 'Ninguém (é de ninguém)']]

# %%
top_tracks_list
# Out:
# [['Maps',
#   'Payphone',
#   'Moves Like Jagger - Studio Recording From "The Voice" Performance',
#   'Memories',
#   'This Love'],
#  ['A paixão (Segundo Nicolau da Viola)',
#   'Não há estrelas no céu',
#   'Porto Côvo',
#   'Nunca me esqueci de ti - Live',
#   'Porto sentido'],
#  ['Mentira',
#   'Ninguém é de ninguém',
#   'Fazes-me Falta',
#   'Mentira',
#   'Ninguém (é de ninguém)']]

# %%
import pandas as pd 
df_list_artist = pd.DataFrame(top_tracks_list, index=artists, columns=["Track 1", "Track 2", "Track 3", "Track 4", "Track 5"])
df_list_artist
# Out:
#                                              Track 1                 Track 2  \
# maroon 5                                        Maps                Payphone
# Rui Veloso       A paixão (Segundo Nicolau da Viola)  Não há estrelas no céu
# Joao Pedro Pais                              Mentira    Ninguém é de ninguém
#
#                                                            Track 3  \
# maroon 5         Moves Like Jagger - Studio Recording From "The...
# Rui Veloso                                              Porto Côvo
# Joao Pedro Pais                                     Fazes-me Falta
#
#                                        Track 4                 Track 5
# maroon 5                              Memories               This Love
# Rui Veloso       Nunca me esqueci de ti - Live           Porto sentido
# Joao Pedro Pais                        Mentira  Ninguém (é de ninguém)

# %%
# 3. **Discover Related Artists**:
    
    #- This function should accept an artist"s name and return the names of the first 5 artists related to the provided artist.
    #- Store the results in a list named `related_artists_list`.

# %%
#- Write a function named `find_related_artists`.


client_id = "4109b2d9f5014671863bb2df1d1fbdd3"
client_secret = "5cb719fae80c4191a9c0b288f51bfe50"



client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)




def get_related_artists(artist_name):
    results = sp.search(q="artist:" + artist_name, type="artist")
    artist_id = results["artists"]["items"][0]["id"]
    related_artists = sp.artist_related_artists(artist_id)["artists"]
    related_artists_list = [artist["name"] for artist in related_artists][:5]
    return related_artists_list

artist_name = "Rui Veloso"

related_artists_list = get_related_artists(artist_name)


df_related_artists_list = pd.DataFrame(related_artists_list, columns=["Artista Relacionado"])

df_related_artists_list
# Out:
#   Artista Relacionado
# 0     Pedro Abrunhosa
# 1                 GNR
# 2            José Cid
# 3   Ala Dos Namorados
# 4         Paulo Gonzo

# %%
# 4. **Iterating for Multiple Artists**:
#    - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.

# %%
artists = ["maroon 5", "Rui Veloso", "Joao Pedro Pais"]

related_artists_list = [get_related_artists(artist) for artist in artists]


for i, artist in enumerate(artists):
    print(f"Related artists for {artist} are: {related_artists_list[i]}")
# Out:
# Related artists for maroon 5 are: ['OneRepublic', 'Jason Mraz', 'Train', 'The Script', 'The Chainsmokers']
# Related artists for Rui Veloso are: ['Pedro Abrunhosa', 'GNR', 'José Cid', 'Ala Dos Namorados', 'Paulo Gonzo']
# Related artists for Joao Pedro Pais are: ['André Sardet', 'Pólo Norte', 'Paulo Gonzo', 'Delfins', 'Mafalda Veiga']

# %%
related_artists_list
# Out:
# [['OneRepublic', 'Jason Mraz', 'Train', 'The Script', 'The Chainsmokers'],
#  ['Pedro Abrunhosa', 'GNR', 'José Cid', 'Ala Dos Namorados', 'Paulo Gonzo'],
#  ['André Sardet', 'Pólo Norte', 'Paulo Gonzo', 'Delfins', 'Mafalda Veiga']]

# %%
related_artists_combined = sum(related_artists_list,[])
print(related_artists_combined)
# Out:
# ['OneRepublic', 'Jason Mraz', 'Train', 'The Script', 'The Chainsmokers', 'Pedro Abrunhosa', 'GNR', 'José Cid', 'Ala Dos Namorados', 'Paulo Gonzo', 'André Sardet', 'Pólo Norte', 'Paulo Gonzo', 'Delfins', 'Mafalda Veiga']

# %%
All_art_combind = related_artists_combined + artists
All_art_combind
# Out:
# ['OneRepublic',
#  'Jason Mraz',
#  'Train',
#  'The Script',
#  'The Chainsmokers',
#  'Pedro Abrunhosa',
#  'GNR',
#  'José Cid',
#  'Ala Dos Namorados',
#  'Paulo Gonzo',
#  'André Sardet',
#  'Pólo Norte',
#  'Paulo Gonzo',
#  'Delfins',
#  'Mafalda Veiga',
#  'maroon 5',
#  'Rui Veloso',
#  'Joao Pedro Pais']

# %%
import requests

client_id = "4109b2d9f5014671863bb2df1d1fbdd3"
client_secret = "5cb719fae80c4191a9c0b288f51bfe50"



def get_top_tracks(artist_name):
  
    url = "https://accounts.spotify.com/api/token"
    auth_response = requests.post(url, {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret,})
    
    
    
    
    auth_response_data = auth_response.json()
    access_token = auth_response_data["access_token"]
    
    

    search_url = f"https://api.spotify.com/v1/search?q={artist_name}&type=artist"
    search_response = requests.get(search_url, headers={
        "Authorization": f"Bearer {access_token}"})
    
    
    artist_data = search_response.json()
    
    if "artists" in artist_data and "items" in artist_data["artists"] and len(artist_data["artists"]["items"]) > 0:
        artist_id = artist_data["artists"]["items"][0]["id"]
        top_tracks_url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks?country=US"
        top_tracks_response = requests.get(top_tracks_url, headers={
            "Authorization": f"Bearer {access_token}"})
        top_tracks_data = top_tracks_response.json()
        
        top_tracks = [track["name"] for track in top_tracks_data["tracks"][:5]]
        return top_tracks
    else:
        return []


artists = All_art_combind



top_tracks_list = [get_top_tracks(artist) for artist in artists]
print(top_tracks_list)
# Out:
# [["I Ain't Worried", 'Counting Stars', 'Sunshine', 'Run', 'I Lived'], ["I'm Yours", 'Lucky', "I Won't Give Up", '93 Million Miles', 'Have It All'], ['Hey, Soul Sister', 'Drops of Jupiter (Tell Me)', 'Drive By', 'Shake Up Christmas', '50 Ways to Say Goodbye'], ['Hall of Fame (feat. will.i.am)', 'Breakeven', "The Man Who Can't Be Moved", 'Superheroes', 'For the First Time'], ['Something Just Like This', 'Closer', 'Jungle', "Don't Let Me Down", 'Paris'], ['Que O Amor Te Salve Nesta Noite Escura - Ao Vivo', 'Tudo O Que Eu Te Dou', 'Eu Não Sei Quem Te Perdeu', 'Se Eu Fosse Um Dia O Teu Olhar', 'Para Os Braços Da Minha Mãe'], ["Sweet Child O' Mine", 'Welcome To The Jungle', 'Paradise City', 'November Rain', "Knockin' On Heaven's Door"], ['Cabana Junto À Praia', 'Nini Dos Meus Quinze Anos', 'Ontem Hoje E Amanhã', 'Cai Neve Em Nova York', 'A Minha Música'], ['Loucos de Lisboa', 'Solta-se o beijo - Ao Vivo', 'A história de Zé Passarinho', 'Fim do mundo (E ao cabo do teu ser)', 'Ele e Ela'], [
# ...

# %%
df_list_artist = pd.DataFrame(top_tracks_list, index=artists, columns=["Track 1", "Track 2", "Track 3", "Track 4", "Track 5"])
df_list_artist
# Out:
#                                                             Track 1  \
# OneRepublic                                         I Ain't Worried
# Jason Mraz                                                I'm Yours
# Train                                              Hey, Soul Sister
# The Script                           Hall of Fame (feat. will.i.am)
# The Chainsmokers                           Something Just Like This
# Pedro Abrunhosa    Que O Amor Te Salve Nesta Noite Escura - Ao Vivo
# GNR                                             Sweet Child O' Mine
# José Cid                                       Cabana Junto À Praia
# Ala Dos Namorados                                  Loucos de Lisboa
# Paulo Gonzo                                                  Não Dá
# André Sardet                                            Foi Feitiço
# Pólo Norte                                      Deixa o Mundo Girar
# Paulo Gonzo                                                  Não Dá
# ...

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify"s featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform"s homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you"ve fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Os grandes hits reunidos numa playlist única! Foto: Teddy Swims.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0rV7skaITBo'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0rV7skaITBo',
#     'id': '37i9dQZF1DX0rV7skaITBo',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000263d5158756bde59f50c64f03',
#       'width': None}],
#     'name': 'Hot Hits Portugal',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %% [markdown]
# ### Getting a Playlist"s Details
# To fetch details about a specific playlist, you can use the playlist method. You"ll need the playlist"s Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)
playlist
# Out:
# {'collaborative': False,
#  'description': 'Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXd9zR7tdziuQ'},
#  'followers': {'href': None, 'total': 916187},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXd9zR7tdziuQ?additional_types=track',
#  'id': '37i9dQZF1DXd9zR7tdziuQ',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f0000000398d0469b38a1f2c0ab59ea95',
#    'width': None}],
#  'name': 'Hits acústicos',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#ffffff',
#  'public': False,
#  'snapshot_id': 'MCxlZjc1ODk5NGUwZjU4NGRiYzMwZDFlNTVmYjNiMjdkMGRlZjA0OWZj',
# ...

# %%
print(playlist["name"])  # Print the playlist"s name
print(playlist["description"])  # Print the playlist"s description
# Out:
# Hits acústicos
# Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks["items"]:
    print(track["track"]["name"])  # Print each track"s name
# Out:
# Take Me Home, Country Roads
# Time After Time
# True Colours
# Days Like This
# Stay With Me - Live From Spotify Berlin
# September Song - Guitar Acoustic
# Cold Heart - Acoustic
# Sunday Morning - Acoustic
# Too Good At Goodbyes - Acoustic
# Wild Love - Acoustic
# La Vie En Rose
# You Are My Sunshine
# Collide - Acoustic Version
# I'm Not the Only One - Live from Spotify, London
# Baby One More Time - Recorded at Spotify Studios New York City
# Better Together
# Stand By Me
# If You Ever Wanna Be In Love - James Bay Spotify Session 2015
# No One - Acoustic
# When You Love Someone - Acoustic
# Dreams - Piano Version
# Shape of You - Acoustic
# Naked - Acoustic Version
# Let It Go - James Bay Spotify Session 2015
# What About Us - Acoustic
# Something Just Like This - Acoustic
# Perfect - Acoustic
# Set Fire to the Rain - Cover
# Ain't Nobody (Loves Me Better) - Acoustic
# Little Talks
# Blinding Lights
# Issues - Acoustic
# Rockabye - Acoustic Version
# 1973 - Acoustic
# Rather Be
# ...

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you"d typically follow these steps:
#
# 1. Fetch the playlist"s tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks["items"]:
    track = track_item["track"]
    for artist in track["artists"]:
        artist_name = artist["name"]
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lana Del Rey', 'Iron & Wine', 'Tom Odell', 'Dermot Kennedy', 'Angus & Julia Stone', 'JP Cooper', 'Elton John', 'Dua Lipa', 'Maroon 5', 'Sam Smith', 'James Bay', 'Daniela Andrade', 'Jasmine Thompson', 'Howie Day', 'Ed Sheeran', 'Us The Duo', 'Florence + The Machine', 'Alicia Keys', 'James TW', 'Lissie', 'James Arthur', 'Thomas Daniel', 'Missy & Blonde', 'Julia Ross', 'Noah Guthrie', 'Julia Sheer', 'Jon D', 'Ouvindo', 'Julia Michaels', 'The Mayries', 'James Blunt', 'Niall Horan', 'Lauv', 'Freedom Fry', 'Charlie Puth', 'Kacey Musgraves', 'Tom Speight', 'Lydia Clowes', 'Eddie Berman', 'Aaron Krause', 'Liza Anne', 'Calum Scott', 'Kygo', 'Conrad Sewell', 'Colin & Caroline', 'Twin Bandit', 'Joshua Hyslop', 'The Wind and The Wave', 'Run River North', 'John Mayer', 'Lotte Kestner', 'Sixpence None The Richer', 'Taken By Trees', 'Jessie J', 'Megan Davies', 'Keelan Donovan', 'John Legend', 'Jonas Blue', 'William Singe', 'Halloran & Kate', 'Sara Farell', 'Passenger', 'Joy Williams', 'Lily Allen
# ...

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify"s current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
#1. **Featured Exploration**: 
# - Fetch the list of Spotify"s current featured playlists. 
# - Extract and display the names and IDs of the top 5 featured playlists.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_id = "4109b2d9f5014671863bb2df1d1fbdd3"
client_secret = "5cb719fae80c4191a9c0b288f51bfe50"



client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


featured_playlists = sp.featured_playlists(limit=5)  # Fetch the 5 list of current featured playlists


for playlist in featured_playlists["playlists"]["items"]: # Extract the names and IDs of featured playlists
    playlist_name = playlist["name"]  # save the name of the playlist
    playlist_id = playlist["id"]      # save the id of the playlist
    print("Playlist Name:", playlist_name)  # print the name of the playlist
    print("Playlist ID:", playlist_id)      # print the id of the playlist
    print("________________________________________________")
    print("                                                ")
# Out:
# Playlist Name: Hot Hits Portugal
# Playlist ID: 37i9dQZF1DX0rV7skaITBo
# ________________________________________________
#
# Playlist Name: Top Brasil
# Playlist ID: 37i9dQZF1DX0FOF1IUWK1W
# ________________________________________________
#
# Playlist Name: Funk Hits
# Playlist ID: 37i9dQZF1DWTkIwO2HDifB
# ________________________________________________
#
# Playlist Name: Pop PT
# Playlist ID: 37i9dQZF1DX6ViL9RcFABv
# ________________________________________________
#
# Playlist Name: Today’s Top Hits
# Playlist ID: 37i9dQZF1DXcBWIGoYBM5M
# ________________________________________________

# %%
#2. **Deep Dive**:
#  - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#  - Fetch and display its name, description, and total track count.

# %%
playlist_id = "37i9dQZF1DXcBWIGoYBM5M"
playlist = sp.playlist(playlist_id)
playlist
# Out:
# {'collaborative': False,
#  'description': 'SZA is on top of the Hottest 50!',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#  'followers': {'href': None, 'total': 34371184},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M?additional_types=track',
#  'id': '37i9dQZF1DXcBWIGoYBM5M',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f000000035d8702ead7f24cd310c571c1',
#    'width': None}],
#  'name': 'Today’s Top Hits',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#FFFFFF',
#  'public': True,
#  'snapshot_id': 'MCxhMDdjMTI5ZjYyZDE4YzQyOWViNGMzZTMzOThkNmFkOGUwYWM2NjY1',
# ...

# %%
 
Playlist_ID = "37i9dQZF1DX6ViL9RcFABv"


playlist_details = sp.playlist(Playlist_ID)  # Fetch the details of the chosen playlist

playlist_name = playlist_details['name']                    # Extract the name    
playlist_description = playlist_details['description']      # Extract the description
total_tracks = playlist_details['tracks']['total']          # Extract the total track count

# Display the fetched details
print("The name of the playlist is:", playlist_name)
print("The Description of the playlist:", playlist_description)
print("And the total track of the playlist is :", total_tracks)
# Out:
# The name of the playlist is: Pop PT
# The Description of the playlist: Uma playlist de pura alma pop! Foto: Nena.
# And the total track of the playlist is : 75

# %%
playlist_details
# Out:
# {'collaborative': False,
#  'description': 'Uma playlist de pura alma pop! Foto: Nena.',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6ViL9RcFABv'},
#  'followers': {'href': None, 'total': 105982},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6ViL9RcFABv?additional_types=track',
#  'id': '37i9dQZF1DX6ViL9RcFABv',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f00000003f450c12aecd5ee02d11d97f6',
#    'width': None}],
#  'name': 'Pop PT',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#ffffff',
#  'public': False,
#  'snapshot_id': 'MCxhYmI1N2ZlMWM0OTU5MzQwNzI2NDc3OWI1NTc3NjJkN2E3NjIxYzUz',
# ...

# %%
#3. **Track-tastic**:
#  - Extract and display the names of the first 10 tracks in the chosen playlist.

# %%
Playlist_Name = "Pop PT"
Playlist_ID = "37i9dQZF1DX6ViL9RcFABv"

chosen_playlist_tracks = sp.playlist_tracks(Playlist_ID, limit=10)


track_names_list = []     # Create a empty list to save the track names

print("Names of the first 10 tracks in the chosen playlist:")
for track in chosen_playlist_tracks["items"]:
    track_name = track["track"]["name"]
    track_names_list.append(track_name)  # Append the track name to the list
    print(track_name)

print("Track names list:", track_names_list)
# Out:
# Names of the first 10 tracks in the chosen playlist:
# Até ao Fim
# Filho
# Brutos Diamantes
# Pelos Cantos do Mundo
# É o que é
# Mãe
# Borboleta
# Cacau - Tema de Genérico
# Na Escola
# Caladinho
# Track names list: ['Até ao Fim', 'Filho', 'Brutos Diamantes', 'Pelos Cantos do Mundo', 'É o que é', 'Mãe', 'Borboleta', 'Cacau - Tema de Genérico', 'Na Escola', 'Caladinho']

# %%
# Just to have a better viwe I crated a Dataframe

# %%
track_names = track_names_list

df = pd.DataFrame({"Track Name": track_names})
df.index += 1                                       # to start in 1 and not in zero
display(df)
# Out:
#                   Track Name
# 1                 Até ao Fim
# 2                      Filho
# 3           Brutos Diamantes
# 4      Pelos Cantos do Mundo
# 5                  É o que é
# 6                        Mãe
# 7                  Borboleta
# 8   Cacau - Tema de Genérico
# 9                  Na Escola
# 10                 Caladinho

# %%
# 4. **Artistic Flair**:
# - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
# - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
Playlist_Name = "Pop PT"
Playlist_ID = "37i9dQZF1DX6ViL9RcFABv"

chosen_playlist_tracks = sp.playlist_tracks(Playlist_ID, limit=10)  # Get the first 10 tracks in the chosen playlist
track_artists_dict = {}                                             # Create a empty dictionary to save the track names

print("Names of the first 10 tracks in the chosen playlist:")
for track in chosen_playlist_tracks["items"]:
    track_name = track["track"]["name"]
    artists_list = [artist["name"] for artist in track["track"]["artists"]]
    track_artists_dict[track_name] = artists_list  
    print("track name:", track_name, "Artists:", artists_list)

print("Track artists dictionary:", track_artists_dict)              # Display the dictionary of track names and associated artists
# Out:
# Names of the first 10 tracks in the chosen playlist:
# track name: Até ao Fim Artists: ['Maninho']
# track name: Filho Artists: ['David Carreira']
# track name: Brutos Diamantes Artists: ['SYRO', 'Bispo']
# track name: Pelos Cantos do Mundo Artists: ['Mickael Carreira', 'Matias Damásio']
# track name: É o que é Artists: ['Nena']
# track name: Mãe Artists: ['D.A.M.A']
# track name: Borboleta Artists: ['David Carreira']
# track name: Cacau - Tema de Genérico Artists: ['SYRO', 'GIULIA BE']
# track name: Na Escola Artists: ['Os Quatro e Meia']
# track name: Caladinho Artists: ['Mickael Carreira']
# Track artists dictionary: {'Até ao Fim': ['Maninho'], 'Filho': ['David Carreira'], 'Brutos Diamantes': ['SYRO', 'Bispo'], 'Pelos Cantos do Mundo': ['Mickael Carreira', 'Matias Damásio'], 'É o que é': ['Nena'], 'Mãe': ['D.A.M.A'], 'Borboleta': ['David Carreira'], 'Cacau - Tema de Genérico': ['SYRO', 'GIULIA BE'], 'Na Escola': ['Os Quatro e Meia'], 'Caladinho': ['Mickael Carreira']}

# %%
df_full_list = pd.DataFrame(list(track_artists_dict.items()), columns=["Track Name", "Artists"])


df_full_list.index += 1 # to start in 1 and not in zero
display(df_full_list)
# Out:
#                   Track Name                             Artists
# 1                 Até ao Fim                           [Maninho]
# 2                      Filho                    [David Carreira]
# 3           Brutos Diamantes                       [SYRO, Bispo]
# 4      Pelos Cantos do Mundo  [Mickael Carreira, Matias Damásio]
# 5                  É o que é                              [Nena]
# 6                        Mãe                           [D.A.M.A]
# 7                  Borboleta                    [David Carreira]
# 8   Cacau - Tema de Genérico                   [SYRO, GIULIA BE]
# 9                  Na Escola                  [Os Quatro e Meia]
# 10                 Caladinho                  [Mickael Carreira]
